# %%
library(ggplot2)
#library(ggExtra)
library(tidyr)
library(dplyr)
library(glue)
library(stringr)

# %% [markdown]
# ### REAL DATA

# %% [markdown]
# #### SDM optimisation

# %%
calculated_keys = read.csv(file = '../dataset/knownpdb/muts_with_answers.txt', sep='\t', stringsAsFactors=F, header = F) %>%
    separate(V1, c('PDB', 'POS', 'WT', 'MUT'), sep = "[-]+", remove = T) %>%
    distinct()

# %%
paths = glue('../SDM2/work/known/{1:length(calculated_keys$PDB)-1}_{calculated_keys$PDB}_{calculated_keys$POS}_{calculated_keys$WT}_{calculated_keys$MUT}/{calculated_keys$PDB}_results/')
paths = lapply(paths, function(i) paste0(i, dir(i, pattern='*.csv')))
paths = paths[str_length(paths) > 60]

# %%
raw.SDM.table <- do.call(rbind,lapply(paths, read.csv, sep=',', header=T, stringsAsFactors=FALSE))
#head(raw.table)
#print(raw.table)

# %%
res.SDM <- raw.SDM.table %>%
    #select(PDB.file, Mutation, Predicted.ddg) %>%
    separate(Mutation, c('WILD', 'MUT'), sep = "[:digit:]+", remove = FALSE) %>%
    mutate(Mutation = gsub("[^0-9.-]", "", Mutation)) %>% 
    extract(PDB.file, c('PDB'), '(....).pdb') %>%
    rename(WT = WILD, POS = Mutation, PRED_DDG = Predicted.ddg) %>%
    mutate(WT = gsub('J', 'C', WT), MUT = gsub('J', 'C', MUT)) %>%
    arrange(PDB, as.numeric(POS), WT, MUT) %>%
    unite(key, c('PDB', 'WT', 'POS', 'MUT'), remove = F)

# %%
get_opt_sdm <- function(sdm, rsa){
    opt_sdm = sdm
    
    if (sdm <= -0.915){
        opt_sdm =  0.2722*sdm + 0.0154*rsa - 1.4323
    }
    if (sdm > -0.915){
        if (rsa <= 42.15){
                if (sdm <= 0.515){
                    opt_sdm = 0.0178*sdm + 0.0001*rsa - 1.0598
                }
                if (sdm > 0.515){
                    if(rsa <= 2.7){
                        if(rsa <= 0.95){
                            opt_sdm = 0.0969*sdm + 0.1263*rsa - 0.5924
                        }
                        if(rsa > 0.95){
                            opt_sdm = 0.5593*sdm + 0.2183*rsa - 0.7658
                        }
                    }
                    if(rsa > 2.7){
                        if(sdm <= 1.955){
                            opt_sdm = 0.0485*sdm + 0.0166*rsa - 1.2056
                        }
                        if(sdm > 1.955){
                            opt_sdm =  0.0678*sdm + 0.0023*rsa - 0.4887
                        }
                    }
                }
        }
        if(rsa > 42.15){
            opt_sdm = 0.1839*sdm + 0.0089*rsa - 0.9346
        }
    }

    return(opt_sdm)
}

# %%
res.SDM2 <- raw.SDM.table %>%
    select(PDB.file, Mutation, Predicted.ddg, MT_RSA..., WT_RSA...) %>%
    separate(Mutation, c('WILD', 'MUT'), sep = "[:digit:]+", remove = FALSE) %>%
    mutate(Mutation = gsub("[^0-9.-]", "", Mutation)) %>% 
    extract(PDB.file, c('PDB'), '(....).pdb') %>%
    rename(WT = WILD, POS = Mutation, PRED_DDG = Predicted.ddg, MT_RSA = MT_RSA..., WT_RSA = WT_RSA...) %>%
    mutate(WT = gsub('J', 'C', WT), MUT = gsub('J', 'C', MUT)) %>%
    mutate(PRED_DDG = mapply(get_opt_sdm, as.numeric(PRED_DDG), as.numeric(MT_RSA))) %>%
    arrange(PDB, as.numeric(POS), WT, MUT) %>%
    unite(key, c('PDB', 'WT', 'POS', 'MUT'), remove = F)

# %%
paths = glue('../mCSM/known/')
paths = sapply(paths, function(i) paste0(i, dir(i, pattern='*.csv')))
#paths = paths[str_length(paths) > 60]

# %%
raw.mCSM.table <- do.call(rbind,lapply(paths, read.csv, sep='\t', header=T, stringsAsFactors=FALSE,
                                       colClasses = c(rep("character", 3), "numeric", "character", rep("numeric", 2))))
#print(raw.mCSM.table)
res.mCSM <- raw.mCSM.table %>%
    select(PDB_FILE, WILD_RES, RES_POS, MUT_RES, PRED_DDG) %>%
    rename(WT = WILD_RES, POS = RES_POS, PDB = PDB_FILE, MUT = MUT_RES) %>%
    extract(PDB, c('PDB'), '(....).pdb') %>%
    arrange(PDB, as.numeric(POS), WT, MUT) %>%
    unite(key, c('PDB', 'WT', 'POS', 'MUT'), remove = F)

# %%
paths = glue('../MAESTRO_linux_x64/work/known/')
paths = sapply(paths, function(i) paste0(i, dir(i, pattern='*.csv')))

# %%
raw.MAESTRO.table <- do.call(rbind,lapply(paths, function(i)
    read.table(i, sep='\t', header=F, stringsAsFactors=FALSE, row.names=NULL)[1:7]))
colnames(raw.MAESTRO.table) <- c('structure', 'seqlength', 'mutation', 'score', 'delta_score', 'ddG', 'ddG_confidence')

# %%
res.MAESTRO <- raw.MAESTRO.table %>%
    select(structure, mutation, ddG) %>%
    extract(structure, c("structure"), "knownpdb/(....)") %>%
    extract(mutation, c("WT", "POS", "MUT"), "(.)(\\d+)..\\{(.)\\}") %>%
    rename(PDB = structure, PRED_DDG = ddG) %>%
    arrange(PDB, as.numeric(POS), WT, MUT) %>%
    unite(key, c('PDB', 'WT', 'POS', 'MUT'), remove = F)
    #separate(mutation, c('WILD_RES', 'MUT_RES'), sep = "[:digit:]+", remove = FALSE) %>%
dim(res.MAESTRO)
# Out:
# [1] 1332    6

# %%
paths = glue('../MuPro/workdir/res/')
paths = sapply(paths, function(i) paste0(i, dir(i, pattern='*.dat')))

# %%
files = lapply(paths, read.csv, sep='\t', header=T, stringsAsFactors=FALSE)
#print(length(files))
paths = paths[sapply(files, nrow) == 1]
files = files[sapply(files, nrow) == 1]
#print(length(files))
rownames(paths) <- NULL
files = sapply(files, function(i) i[1])
raw.MuPro.table <- as.vector(do.call(rbind, files))
names(raw.MuPro.table) <- NULL
#print(length(paths))

# %%
res.MuPro = cbind(paths, raw.MuPro.table)
res.MuPro = as.data.frame(res.MuPro) %>%
    extract(raw.MuPro.table, c("PRED_DDG"), "(-*\\d+.\\d+)") %>%
    extract(paths, c('PDB', 'POS', 'WT', 'MUT'), '/\\d+_(....)_(\\d+)_(.)_(.).dat') %>%
    arrange(PDB, as.numeric(POS), WT, MUT) %>%
    unite(key, c('PDB', 'WT', 'POS', 'MUT'), remove = F)

# %%
paths = '../CUPSAT/known/'
paths = sapply(paths, function(i) paste0(i, dir(i, pattern='*csv')))

# %%
mut_keys = unite(res.SDM, key, c('PDB', 'WT', 'POS', 'MUT'))$key

# %%
real.table = read.csv(file = '../dataset/full_dataset.csv', sep='\t') %>%
    select(PDB.ID.with.modifications.to.be.made, Mutation, ddG..kcal.mol..positive.is.stable, pH, 'T') %>%
    rename(PDB = PDB.ID.with.modifications.to.be.made, DDG = ddG..kcal.mol..positive.is.stable) %>%
    group_by(PDB, Mutation) %>%
    summarise_at('DDG', funs(mean)) %>%
    separate(Mutation, c('WT', 'POS', 'MUT')) %>%
    arrange(PDB, as.numeric(POS), WT, MUT) %>%
    unite(key, c('PDB', 'WT', 'POS', 'MUT'))
    
y_val = subset(real.table, real.table$key %in% mut_keys)$DDG

# %%
#aggr = cbind(res.SDM$PRED_DDG, -res.MAESTRO$PRED_DDG, res.mCSM$PRED_DDG)
#colnames(aggr) = c('SDM', 'MAESTRO', 'mCSM')
#boxplot(aggr)
cor(as.numeric(subset(res.MuPro, res.MuPro$key %in% res.SDM$key)$PRED_DDG), subset(real.table, real.table$key %in% res.MuPro$key & real.table$key %in% res.SDM$key)$DDG)
cor(subset(res.SDM, res.SDM$key %in% res.MuPro$key)$PRED_DDG, subset(real.table, real.table$key %in% res.MuPro$key & real.table$key %in% res.SDM$key)$DDG)
cor(subset(res.SDM2, res.SDM2$key %in% res.MuPro$key)$PRED_DDG, subset(real.table, real.table$key %in% res.MuPro$key & real.table$key %in% res.SDM2$key)$DDG)
cor(subset(res.mCSM, res.mCSM$key %in% res.MuPro$key)$PRED_DDG, subset(real.table, real.table$key %in% res.MuPro$key & real.table$key %in% res.mCSM$key)$DDG)
-cor(subset(res.MAESTRO, res.MAESTRO$key %in% res.MuPro$key)$PRED_DDG, subset(real.table, real.table$key %in% res.MuPro$key & real.table$key %in% res.MAESTRO$key)$DDG)

#cor(res.mCSM$PRED_DDG, y_val)
#cor(-res.MAESTRO$PRED_DDG, y_val)
# Out:
# [1] 0.3816605
# [1] 0.4898656
# [1] 0.5051098
# [1] 0.5478027
# [1] 0.5665372

# %%
sdm_pred = subset(res.SDM2)$PRED_DDG
sdm_true = subset(real.table,real.table$key %in% res.SDM$key)$DDG

plot(sdm_true, sdm_pred)
abline(lm(sdm_true ~ sdm_pred), 'red')
cor(sdm_true, sdm_pred)
# Out:
# [1] 0.5310916
# plot without title

# %%
plot(res.SDM$WT_OSP, res.SDM$PRED_DDG - subset(real.table, real.table$key %in% res.SDM$key)$DDG)

plot(res.SDM$WT_DEPTH..angstrom., res.SDM$PRED_DDG - subset(real.table, real.table$key %in% res.SDM$key)$DDG)

plot(res.SDM$WT_RSA..., res.SDM$PRED_DDG - subset(real.table, real.table$key %in% res.SDM$key)$DDG)
# Out:
# plot without title
# plot without title
# plot without title

# %%
res.SDM
# Out:
#      key          PDB  Chain.ID POS WT MUT WT_SSE WT_RSA... WT_DEPTH..angstrom.
# 1    1A0F_S_11_A  1A0F A        11  S  A   a       0.0      7.91
# 2    1A5E_D_74_N  1A5E A        74  D  N   b      15.6      4.18
# 3    1A5E_P_81_L  1A5E A        81  P  L   H       0.0      8.53
# 4    1A5E_D_84_N  1A5E A        84  D  N   H       3.2      5.65
# 5    1A7C_R_30_E  1A7C A        30  R  E   b      65.1      3.27
# 6    1A7C_E_350_P 1A7C A        350 E  P   E      66.7      3.37
# 7    1A7C_E_350_R 1A7C A        350 E  R   E      66.7      3.37
# 8    1AG2_Y_155_H 1AG2 A        155 Y  H   a      62.8      3.48
# 9    1AG2_H_187_R 1AG2 A        187 H  R   H      17.2      4.36
# 10   1AG2_H_187_Y 1AG2 A        187 H  Y   H      17.2      4.36
# 11   1AG2_E_196_K 1AG2 A        196 E  K   p      17.4      4.16
# 12   1AG2_F_198_H 1AG2 A        198 F  H   b       2.5      6.70
# 13   1AYF_F_11_W  1AYF A        11  F  W   E       0.0      8.67
# 14   1AYF_F_43_W  1AYF A        43  F  W   p       0.4      7.22
# 15   1AYF_F_59_W  1AYF A        59  F  W   b       0.0      8.89
# 16   1AYF_F_64_W  1AYF A        64  F  W   H      29.7      4.35
# 17   1AYI_L_3_A   1AYI A        3   L  A   b      36.0      3.73
# 18   1AYI_A_13_N  1AYI A        13  A  N   H      93.2      3.00
# 19   1AYI_V_16_A  1AYI A        16  V  A   H      34.2      3.68
# 20   1AYI_I_22_V  1AYI A        22  I  V   H       0.9      7.41
# 21   1AYI_L_34_A  1AYI A        34  L  A   H      10.8      5.05
# 22   1AYI_L_38_A  1AYI A        38  L  A   H      20.0      4.25
# 23   1AYI_V_42_A  1AYI A        42  V  A   H      51.2      3.41
# 24   1AYI_I_44_V  1AYI A        44  I  V   H       7.9      5.68
# 25   1AYI_L_53_A  1AYI A        53  L  A   H       4.4      6.66
# 26   1AYI_I_68_V  1AYI A        68  I  V   H       9.2      7.13
# 27   1AYI_V_69_A  1AYI A        69  V  A   H       3.4      5.30
# 28   1B10_F_175_W 1B10 A        175 F  W   H       0.5      7.77
# 29   1B10_F_198_W 1B10 A        198 F  W   p      32.3      4.33
# 30   1BA3_H_461_D 1BA3 A        461 H  D   p      21.1      4.18
# ⋮    ⋮            ⋮    ⋮        ⋮   ⋮  ⋮   ⋮      ⋮         ⋮
# 1303 5EMZ_I_23_G  5EMZ A        23  I  G   H       0.0      8.23
# 1304 5EMZ_I_23_V  5EMZ A        23  I  V   H       0.0      8.23
# 1305 5EMZ_V_26_A  5EMZ A        26  V  A   H       0.0      8.10
# 1306 5EMZ_K_27_A  5EMZ A        27  K  A   H       2.2      6.37
# 1325 0.361  ⋯ 0     E      72.1      3.36                0.206  0     0
# 1326 0.167  ⋯ 0     H      83.0      3.55                0.132  0     0
# 1327 0.345  ⋯ 0     p      66.3      3.51                0.239  0     0
# 1328 0.379  ⋯ 0     E      31.1      3.59                0.311  0     0
# 1329 0.466  ⋯ 0     p      34.0      4.02                0.435  0     0
# 1330 0.364  ⋯ 1     H      16.7      5.67                0.411  0     0
# 1331 0.604  ⋯ 1     H       0.0      7.14                0.532  0     0
# 1332 0.450  ⋯ 0     H      22.3      3.84                0.434  0     0
#      MT_SO PRED_DDG Outcome
# 1    0      0.60    Increased stability
# 2    1      0.19    Increased stability
# 3    0      3.38    Increased stability
# 4    1      0.47    Increased stability
# 5    0     -0.24    Reduced stability
# 6    0     -0.71    Reduced stability
# 7    0     -0.01    Reduced stability
# 8    0     -0.35    Reduced stability
# 9    0      0.13    Increased stability
# 10   1      0.56    Increased stability
# 11   1      0.03    Increased stability
# 12   0     -1.02    Reduced stability
# 13   0     -0.68    Reduced stability
# 14   0     -0.91    Reduced stability
# 15   0     -1.07    Reduced stability
# 16   0      0.49    Increased stability
# 17   0     -0.52    Reduced stability
# 18   0     -1.73    Reduced stability
# 19   0      0.84    Increased stability
# 20   0     -2.57    Reduced stability
# 21   0     -2.66    Reduced stability
# 22   0      0.15    Increased stability
# 23   0      0.84    Increased stability
# 24   0     -2.53    Reduced stability
# 25   0     -3.25    Reduced stability
# 26   0     -2.50    Reduced stability
# 27   0     -0.88    Reduced stability
# 28   1     -0.29    Reduced stability
# 29   0      0.17    Increased stability
# 30   0     -0.93    Reduced stability
# ⋮    ⋮     ⋮        ⋮
# 1303 0     -3.14    Reduced stability
# 1304 0     -2.62    Reduced stability
# 1305 0     -0.88    Reduced stability
# 1306 0     -1.39    Reduced stability
# 1307 0     -1.56    Reduced stability
# 1308 0     -3.15    Reduced stability
# 1309 0     -2.61    Reduced stability
# 1310 0      0.44    Increased stability
# 1311 0     -3.98    Reduced stability
# 1312 0     -3.18    Reduced stability
# 1313 0     -3.56    Reduced stability
# 1314 0     -4.51    Reduced stability
# 1315 0     -2.46    Reduced stability
# 1316 0     -3.96    Reduced stability
# 1317 0     -3.97    Reduced stability
# 1318 1     -2.69    Reduced stability
# 1319 0     -3.68    Reduced stability
# 1320 0      0.63    Increased stability
# 1321 1     -1.41    Reduced stability
# 1322 1     -0.69    Reduced stability
# 1323 0     -2.46    Reduced stability
# 1324 0     -0.69    Reduced stability
# 1325 0     -0.46    Reduced stability
# 1326 0      0.15    Increased stability
# 1327 0     -0.58    Reduced stability
# 1328 0     -1.49    Reduced stability
# 1329 0      0.02    Increased stability
# 1330 0     -0.63    Reduced stability
# 1331 0     -0.62    Reduced stability
# 1332 1     -1.13    Reduced stability

# %% [markdown]
# ## Full dataset for SDM

# %%
calculated_keys = read.csv(file = '../dataset/knownpdb/muts_with_answers.txt', sep='\t', stringsAsFactors=F, header = F) %>%
    separate(V1, c('PDB', 'POS', 'WT', 'MUT'), sep = "[-]+", remove = T) %>%
    distinct()

# %% [markdown]
# ## Artificail dataset

# %%
paths = '/home/al820/stabval/dataset/readypdb/'
paths = unlist(lapply(paths, function(i) paste0(i, dir(i, pattern='*.csv'))))

# %%
muts = read.csv(paths[1], sep = ';', header = F)
muts$PDB = paths[1]
extract(muts, c("PDB"), c("PDB"), "readypdb/(....)")
# Out:
#     V1 V2  V3 PDB
# 1   Y   91 A  1AL0
# 2   Y   91 C  1AL0
# 3   Y   91 D  1AL0
# 4   Y   91 E  1AL0
# 5   Y   91 F  1AL0
# 6   Y   91 G  1AL0
# 7   Y   91 H  1AL0
# 8   Y   91 I  1AL0
# 9   Y   91 K  1AL0
# 10  Y   91 L  1AL0
# 11  Y   91 M  1AL0
# 12  Y   91 N  1AL0
# 13  Y   91 P  1AL0
# 14  Y   91 Q  1AL0
# 15  Y   91 R  1AL0
# 16  Y   91 S  1AL0
# 17  Y   91 T  1AL0
# 18  Y   91 V  1AL0
# 19  Y   91 W  1AL0
# 20  G  118 A  1AL0
# 21  G  118 C  1AL0
# 22  G  118 D  1AL0
# 23  G  118 E  1AL0
# 24  G  118 F  1AL0
# 25  G  118 H  1AL0
# 26  G  118 I  1AL0
# 27  G  118 K  1AL0
# 28  G  118 L  1AL0
# 29  G  118 M  1AL0
# 30  G  118 N  1AL0
# ⋮   ⋮  ⋮   ⋮  ⋮
# 351 A  81  L  1AL0
# 352 A  81  M  1AL0
# 353 A  81  N  1AL0
# 354 A  81  P  1AL0
# 355 A  81  Q  1AL0
# 356 A  81  R  1AL0
# 357 A  81  S  1AL0
# 358 A  81  T  1AL0
# 359 A  81  V  1AL0
# 360 A  81  W  1AL0
# 361 A  81  Y  1AL0
# 362 Q  89  A  1AL0
# 363 Q  89  C  1AL0
# 364 Q  89  D  1AL0
# 365 Q  89  E  1AL0
# 366 Q  89  F  1AL0
# 367 Q  89  G  1AL0
# 368 Q  89  H  1AL0
# 369 Q  89  I  1AL0
# 370 Q  89  K  1AL0
# 371 Q  89  L  1AL0
# 372 Q  89  M  1AL0
# 373 Q  89  N  1AL0
# 374 Q  89  P  1AL0
# 375 Q  89  R  1AL0
# 376 Q  89  S  1AL0
# 377 Q  89  T  1AL0
# 378 Q  89  V  1AL0
# 379 Q  89  W  1AL0
# 380 Q  89  Y  1AL0

# %%
mut.list = do.call(rbind, lapply(paths, function(i){
    muts = read.csv(i, sep = ';', header = F)
    colnames(muts) = c('WT', 'POS', 'MUT')
    muts$PDB = i
    muts <- extract(muts, c("PDB"), c("PDB"), "readypdb/(....)")
    muts <- muts[,c("PDB", "POS", "WT", "MUT")]
    unite(muts, c("PDB", "POS", "WT", "MUT"), sep = '-')
}))

# %%
write(unlist(mut.list), file="../dataset/readypdb/readypdb.txt")
